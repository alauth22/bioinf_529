# %% [markdown]
# # eQTL analysis

# %% [markdown]
# ---
# ## Before Class
# 1. Review previous two classes
# * Review slides on eQTL analsis
#
# ---
# ## Learning Objectives
# 1. Understand bulk processing of data
# * Perform eQTL analysis

# %% [markdown]
# ---
# ## Bulk data processing
# Another way we can predict the effect of variants on expression is through study of the genotypes and not allele-specific expression. For today's class, we have expanded our study to include 100 DNA and RNA samples from diploid individuals from our same small reference genome. Our goal now will be to study if any of the variants in the genome can be associated with the expression of a gene. These variants are said to be eQTLs (expression quantitative trait loci) and help explain variation of expression levels of genes. It is important to note that while the variants are assoiciated with expression changes, they are not necessairly causative of the expression change.
#
# The first step of today's class will be to just process all of the RNA and DNA data by aligning it to the genome and converting to bam files. The RNA bam files will need to be indexed as the previous class.
#
# Hint: A python loop can be put around the shell commands we've previously used and variables can be used in the shell commands by surrounding them with curly brackets '{}'.
# For example:
# ```
# for i in range(10):
#     !echo {i}
# ```

# %%
# Align all of the DNA reads; this will align all the DNA reads. 
for i in range(1, 101):
    # !bowtie2 -f -x ../class_09/sample_genome -U data/DNA/sample_reads_P{i}.fa.gz -S data/DNA/sample_reads_P{i}.sam
    # !samtools sort -o data/DNA/sample_reads_P{i}.bam data/DNA/sample_reads_P{i}.sam
# Out:
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22531 (98.17%) aligned exactly 1 time
#     421 (1.83%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22547 (98.24%) aligned exactly 1 time
#     405 (1.76%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22524 (98.14%) aligned exactly 1 time
#     428 (1.86%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22532 (98.17%) aligned exactly 1 time
#     420 (1.83%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22527 (98.15%) aligned exactly 1 time
#     425 (1.85%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22500 (98.03%) aligned exactly 1 time
#     452 (1.97%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22555 (98.27%) aligned exactly 1 time
#     397 (1.73%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22537 (98.19%) aligned exactly 1 time
#     415 (1.81%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22599 (98.46%) aligned exactly 1 time
#     353 (1.54%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22523 (98.13%) aligned exactly 1 time
#     429 (1.87%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22542 (98.21%) aligned exactly 1 time
#     410 (1.79%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22588 (98.41%) aligned exactly 1 time
#     364 (1.59%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22542 (98.21%) aligned exactly 1 time
#     410 (1.79%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22541 (98.21%) aligned exactly 1 time
#     411 (1.79%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22570 (98.34%) aligned exactly 1 time
#     382 (1.66%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22551 (98.25%) aligned exactly 1 time
#     401 (1.75%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22530 (98.16%) aligned exactly 1 time
#     422 (1.84%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22536 (98.19%) aligned exactly 1 time
#     416 (1.81%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22538 (98.20%) aligned exactly 1 time
#     414 (1.80%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22562 (98.30%) aligned exactly 1 time
#     390 (1.70%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22541 (98.21%) aligned exactly 1 time
#     411 (1.79%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22532 (98.17%) aligned exactly 1 time
#     420 (1.83%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22574 (98.35%) aligned exactly 1 time
#     378 (1.65%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22556 (98.27%) aligned exactly 1 time
#     396 (1.73%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22493 (98.00%) aligned exactly 1 time
#     459 (2.00%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22538 (98.20%) aligned exactly 1 time
#     414 (1.80%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22499 (98.03%) aligned exactly 1 time
#     453 (1.97%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22501 (98.04%) aligned exactly 1 time
#     451 (1.96%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22544 (98.22%) aligned exactly 1 time
#     408 (1.78%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22548 (98.24%) aligned exactly 1 time
#     404 (1.76%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22558 (98.28%) aligned exactly 1 time
#     394 (1.72%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22507 (98.06%) aligned exactly 1 time
#     445 (1.94%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22540 (98.20%) aligned exactly 1 time
#     412 (1.80%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22554 (98.27%) aligned exactly 1 time
#     398 (1.73%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22536 (98.19%) aligned exactly 1 time
#     416 (1.81%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22555 (98.27%) aligned exactly 1 time
#     397 (1.73%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22529 (98.16%) aligned exactly 1 time
#     423 (1.84%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22544 (98.22%) aligned exactly 1 time
#     408 (1.78%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22537 (98.19%) aligned exactly 1 time
#     415 (1.81%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22541 (98.21%) aligned exactly 1 time
#     411 (1.79%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22567 (98.32%) aligned exactly 1 time
#     385 (1.68%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22539 (98.20%) aligned exactly 1 time
#     413 (1.80%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22565 (98.31%) aligned exactly 1 time
#     387 (1.69%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22536 (98.19%) aligned exactly 1 time
#     416 (1.81%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22529 (98.16%) aligned exactly 1 time
#     423 (1.84%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22510 (98.07%) aligned exactly 1 time
#     442 (1.93%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22536 (98.19%) aligned exactly 1 time
#     416 (1.81%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22557 (98.28%) aligned exactly 1 time
#     395 (1.72%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22527 (98.15%) aligned exactly 1 time
#     425 (1.85%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22508 (98.07%) aligned exactly 1 time
#     444 (1.93%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22537 (98.19%) aligned exactly 1 time
#     415 (1.81%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22571 (98.34%) aligned exactly 1 time
#     381 (1.66%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22522 (98.13%) aligned exactly 1 time
#     430 (1.87%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22572 (98.34%) aligned exactly 1 time
#     380 (1.66%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22554 (98.27%) aligned exactly 1 time
#     398 (1.73%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22497 (98.02%) aligned exactly 1 time
#     455 (1.98%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22515 (98.10%) aligned exactly 1 time
#     437 (1.90%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22537 (98.19%) aligned exactly 1 time
#     415 (1.81%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22556 (98.27%) aligned exactly 1 time
#     396 (1.73%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22552 (98.26%) aligned exactly 1 time
#     400 (1.74%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22560 (98.29%) aligned exactly 1 time
#     392 (1.71%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22554 (98.27%) aligned exactly 1 time
#     398 (1.73%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22569 (98.33%) aligned exactly 1 time
#     383 (1.67%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22539 (98.20%) aligned exactly 1 time
#     413 (1.80%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22501 (98.04%) aligned exactly 1 time
#     451 (1.96%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22566 (98.32%) aligned exactly 1 time
#     386 (1.68%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22525 (98.14%) aligned exactly 1 time
#     427 (1.86%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22555 (98.27%) aligned exactly 1 time
#     397 (1.73%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22530 (98.16%) aligned exactly 1 time
#     422 (1.84%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22569 (98.33%) aligned exactly 1 time
#     383 (1.67%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22582 (98.39%) aligned exactly 1 time
#     370 (1.61%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22506 (98.06%) aligned exactly 1 time
#     446 (1.94%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22552 (98.26%) aligned exactly 1 time
#     400 (1.74%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22552 (98.26%) aligned exactly 1 time
#     400 (1.74%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22547 (98.24%) aligned exactly 1 time
#     405 (1.76%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22549 (98.24%) aligned exactly 1 time
#     403 (1.76%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22558 (98.28%) aligned exactly 1 time
#     394 (1.72%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22531 (98.17%) aligned exactly 1 time
#     421 (1.83%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22529 (98.16%) aligned exactly 1 time
#     423 (1.84%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22531 (98.17%) aligned exactly 1 time
#     421 (1.83%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22558 (98.28%) aligned exactly 1 time
#     394 (1.72%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22508 (98.07%) aligned exactly 1 time
#     444 (1.93%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22543 (98.22%) aligned exactly 1 time
#     409 (1.78%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22523 (98.13%) aligned exactly 1 time
#     429 (1.87%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22542 (98.21%) aligned exactly 1 time
#     410 (1.79%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22548 (98.24%) aligned exactly 1 time
#     404 (1.76%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22555 (98.27%) aligned exactly 1 time
#     397 (1.73%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22570 (98.34%) aligned exactly 1 time
#     382 (1.66%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22538 (98.20%) aligned exactly 1 time
#     414 (1.80%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22543 (98.22%) aligned exactly 1 time
#     409 (1.78%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22536 (98.19%) aligned exactly 1 time
#     416 (1.81%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22535 (98.18%) aligned exactly 1 time
#     417 (1.82%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22562 (98.30%) aligned exactly 1 time
#     390 (1.70%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22516 (98.10%) aligned exactly 1 time
#     436 (1.90%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22461 (97.86%) aligned exactly 1 time
#     491 (2.14%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22496 (98.01%) aligned exactly 1 time
#     456 (1.99%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22574 (98.35%) aligned exactly 1 time
#     378 (1.65%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22576 (98.36%) aligned exactly 1 time
#     376 (1.64%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22559 (98.29%) aligned exactly 1 time
#     393 (1.71%) aligned >1 times
# 100.00% overall alignment rate
# 22952 reads; of these:
#   22952 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     22536 (98.19%) aligned exactly 1 time
#     416 (1.81%) aligned >1 times
# 100.00% overall alignment rate

# %%
# Process RNA the same way:
for i in range(1, 101):
    # !bowtie2 -f -x ../class_09/sample_genome -U data/RNA/sample_RNA_reads_P{i}.fa.gz -S data/RNA/sample_RNA_reads_P{i}.sam
    # !samtools sort -o data/RNA/sample_RNA_reads_P{i}.bam data/RNA/sample_RNA_reads_P{i}.sam
    # !samtools index data/RNA/sample_RNA_reads_P{i}.bam
# Out:
# 5755 reads; of these:
#   5755 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5747 (99.86%) aligned exactly 1 time
#     8 (0.14%) aligned >1 times
# 100.00% overall alignment rate
# 5741 reads; of these:
#   5741 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5731 (99.83%) aligned exactly 1 time
#     10 (0.17%) aligned >1 times
# 100.00% overall alignment rate
# 4431 reads; of these:
#   4431 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4426 (99.89%) aligned exactly 1 time
#     5 (0.11%) aligned >1 times
# 100.00% overall alignment rate
# 5372 reads; of these:
#   5372 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5370 (99.96%) aligned exactly 1 time
#     2 (0.04%) aligned >1 times
# 100.00% overall alignment rate
# 5008 reads; of these:
#   5008 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4996 (99.76%) aligned exactly 1 time
#     12 (0.24%) aligned >1 times
# 100.00% overall alignment rate
# 5562 reads; of these:
#   5562 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5551 (99.80%) aligned exactly 1 time
#     11 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 5107 reads; of these:
#   5107 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5100 (99.86%) aligned exactly 1 time
#     7 (0.14%) aligned >1 times
# 100.00% overall alignment rate
# 4726 reads; of these:
#   4726 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4719 (99.85%) aligned exactly 1 time
#     7 (0.15%) aligned >1 times
# 100.00% overall alignment rate
# 5285 reads; of these:
#   5285 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5282 (99.94%) aligned exactly 1 time
#     3 (0.06%) aligned >1 times
# 100.00% overall alignment rate
# 4745 reads; of these:
#   4745 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4738 (99.85%) aligned exactly 1 time
#     7 (0.15%) aligned >1 times
# 100.00% overall alignment rate
# 4563 reads; of these:
#   4563 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4546 (99.63%) aligned exactly 1 time
#     17 (0.37%) aligned >1 times
# 100.00% overall alignment rate
# 4726 reads; of these:
#   4726 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4714 (99.75%) aligned exactly 1 time
#     12 (0.25%) aligned >1 times
# 100.00% overall alignment rate
# 5202 reads; of these:
#   5202 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5188 (99.73%) aligned exactly 1 time
#     14 (0.27%) aligned >1 times
# 100.00% overall alignment rate
# 4708 reads; of these:
#   4708 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4697 (99.77%) aligned exactly 1 time
#     11 (0.23%) aligned >1 times
# 100.00% overall alignment rate
# 5199 reads; of these:
#   5199 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5186 (99.75%) aligned exactly 1 time
#     13 (0.25%) aligned >1 times
# 100.00% overall alignment rate
# 5568 reads; of these:
#   5568 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5557 (99.80%) aligned exactly 1 time
#     11 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 5176 reads; of these:
#   5176 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5159 (99.67%) aligned exactly 1 time
#     17 (0.33%) aligned >1 times
# 100.00% overall alignment rate
# 5187 reads; of these:
#   5187 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5175 (99.77%) aligned exactly 1 time
#     12 (0.23%) aligned >1 times
# 100.00% overall alignment rate
# 5096 reads; of these:
#   5096 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5089 (99.86%) aligned exactly 1 time
#     7 (0.14%) aligned >1 times
# 100.00% overall alignment rate
# 4756 reads; of these:
#   4756 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4745 (99.77%) aligned exactly 1 time
#     11 (0.23%) aligned >1 times
# 100.00% overall alignment rate
# 5527 reads; of these:
#   5527 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5515 (99.78%) aligned exactly 1 time
#     12 (0.22%) aligned >1 times
# 100.00% overall alignment rate
# 5826 reads; of these:
#   5826 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5814 (99.79%) aligned exactly 1 time
#     12 (0.21%) aligned >1 times
# 100.00% overall alignment rate
# 4918 reads; of these:
#   4918 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4904 (99.72%) aligned exactly 1 time
#     14 (0.28%) aligned >1 times
# 100.00% overall alignment rate
# 4902 reads; of these:
#   4902 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4892 (99.80%) aligned exactly 1 time
#     10 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 5353 reads; of these:
#   5353 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5346 (99.87%) aligned exactly 1 time
#     7 (0.13%) aligned >1 times
# 100.00% overall alignment rate
# 5546 reads; of these:
#   5546 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5530 (99.71%) aligned exactly 1 time
#     16 (0.29%) aligned >1 times
# 100.00% overall alignment rate
# 4548 reads; of these:
#   4548 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4533 (99.67%) aligned exactly 1 time
#     15 (0.33%) aligned >1 times
# 100.00% overall alignment rate
# 5549 reads; of these:
#   5549 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5537 (99.78%) aligned exactly 1 time
#     12 (0.22%) aligned >1 times
# 100.00% overall alignment rate
# 4903 reads; of these:
#   4903 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4888 (99.69%) aligned exactly 1 time
#     15 (0.31%) aligned >1 times
# 100.00% overall alignment rate
# 5759 reads; of these:
#   5759 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5749 (99.83%) aligned exactly 1 time
#     10 (0.17%) aligned >1 times
# 100.00% overall alignment rate
# 4448 reads; of these:
#   4448 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4442 (99.87%) aligned exactly 1 time
#     6 (0.13%) aligned >1 times
# 100.00% overall alignment rate
# 4833 reads; of these:
#   4833 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4818 (99.69%) aligned exactly 1 time
#     15 (0.31%) aligned >1 times
# 100.00% overall alignment rate
# 6204 reads; of these:
#   6204 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     6198 (99.90%) aligned exactly 1 time
#     6 (0.10%) aligned >1 times
# 100.00% overall alignment rate
# 4451 reads; of these:
#   4451 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4444 (99.84%) aligned exactly 1 time
#     7 (0.16%) aligned >1 times
# 100.00% overall alignment rate
# 4433 reads; of these:
#   4433 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4426 (99.84%) aligned exactly 1 time
#     7 (0.16%) aligned >1 times
# 100.00% overall alignment rate
# 5168 reads; of these:
#   5168 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5155 (99.75%) aligned exactly 1 time
#     13 (0.25%) aligned >1 times
# 100.00% overall alignment rate
# 5180 reads; of these:
#   5180 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5166 (99.73%) aligned exactly 1 time
#     14 (0.27%) aligned >1 times
# 100.00% overall alignment rate
# 5833 reads; of these:
#   5833 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5821 (99.79%) aligned exactly 1 time
#     12 (0.21%) aligned >1 times
# 100.00% overall alignment rate
# 6222 reads; of these:
#   6222 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     6208 (99.77%) aligned exactly 1 time
#     14 (0.23%) aligned >1 times
# 100.00% overall alignment rate
# 5827 reads; of these:
#   5827 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5818 (99.85%) aligned exactly 1 time
#     9 (0.15%) aligned >1 times
# 100.00% overall alignment rate
# 4089 reads; of these:
#   4089 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4080 (99.78%) aligned exactly 1 time
#     9 (0.22%) aligned >1 times
# 100.00% overall alignment rate
# 5752 reads; of these:
#   5752 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5744 (99.86%) aligned exactly 1 time
#     8 (0.14%) aligned >1 times
# 100.00% overall alignment rate
# 5818 reads; of these:
#   5818 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5807 (99.81%) aligned exactly 1 time
#     11 (0.19%) aligned >1 times
# 100.00% overall alignment rate
# 5728 reads; of these:
#   5728 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5723 (99.91%) aligned exactly 1 time
#     5 (0.09%) aligned >1 times
# 100.00% overall alignment rate
# 5370 reads; of these:
#   5370 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5361 (99.83%) aligned exactly 1 time
#     9 (0.17%) aligned >1 times
# 100.00% overall alignment rate
# 4922 reads; of these:
#   4922 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4913 (99.82%) aligned exactly 1 time
#     9 (0.18%) aligned >1 times
# 100.00% overall alignment rate
# 5197 reads; of these:
#   5197 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5188 (99.83%) aligned exactly 1 time
#     9 (0.17%) aligned >1 times
# 100.00% overall alignment rate
# 5079 reads; of these:
#   5079 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5067 (99.76%) aligned exactly 1 time
#     12 (0.24%) aligned >1 times
# 100.00% overall alignment rate
# 4712 reads; of these:
#   4712 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4701 (99.77%) aligned exactly 1 time
#     11 (0.23%) aligned >1 times
# 100.00% overall alignment rate
# 4905 reads; of these:
#   4905 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4901 (99.92%) aligned exactly 1 time
#     4 (0.08%) aligned >1 times
# 100.00% overall alignment rate
# 6199 reads; of these:
#   6199 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     6181 (99.71%) aligned exactly 1 time
#     18 (0.29%) aligned >1 times
# 100.00% overall alignment rate
# 5184 reads; of these:
#   5184 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5174 (99.81%) aligned exactly 1 time
#     10 (0.19%) aligned >1 times
# 100.00% overall alignment rate
# 5374 reads; of these:
#   5374 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5366 (99.85%) aligned exactly 1 time
#     8 (0.15%) aligned >1 times
# 100.00% overall alignment rate
# 5188 reads; of these:
#   5188 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5177 (99.79%) aligned exactly 1 time
#     11 (0.21%) aligned >1 times
# 100.00% overall alignment rate
# 5554 reads; of these:
#   5554 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5544 (99.82%) aligned exactly 1 time
#     10 (0.18%) aligned >1 times
# 100.00% overall alignment rate
# 4726 reads; of these:
#   4726 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4725 (99.98%) aligned exactly 1 time
#     1 (0.02%) aligned >1 times
# 100.00% overall alignment rate
# 5356 reads; of these:
#   5356 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5350 (99.89%) aligned exactly 1 time
#     6 (0.11%) aligned >1 times
# 100.00% overall alignment rate
# 4729 reads; of these:
#   4729 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4715 (99.70%) aligned exactly 1 time
#     14 (0.30%) aligned >1 times
# 100.00% overall alignment rate
# 4995 reads; of these:
#   4995 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4985 (99.80%) aligned exactly 1 time
#     10 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 4453 reads; of these:
#   4453 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4443 (99.78%) aligned exactly 1 time
#     10 (0.22%) aligned >1 times
# 100.00% overall alignment rate
# 5850 reads; of these:
#   5850 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5834 (99.73%) aligned exactly 1 time
#     16 (0.27%) aligned >1 times
# 100.00% overall alignment rate
# 5821 reads; of these:
#   5821 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5810 (99.81%) aligned exactly 1 time
#     11 (0.19%) aligned >1 times
# 100.00% overall alignment rate
# 5384 reads; of these:
#   5384 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5376 (99.85%) aligned exactly 1 time
#     8 (0.15%) aligned >1 times
# 100.00% overall alignment rate
# 5378 reads; of these:
#   5378 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5369 (99.83%) aligned exactly 1 time
#     9 (0.17%) aligned >1 times
# 100.00% overall alignment rate
# 5091 reads; of these:
#   5091 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5081 (99.80%) aligned exactly 1 time
#     10 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 4933 reads; of these:
#   4933 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4918 (99.70%) aligned exactly 1 time
#     15 (0.30%) aligned >1 times
# 100.00% overall alignment rate
# 5824 reads; of these:
#   5824 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5811 (99.78%) aligned exactly 1 time
#     13 (0.22%) aligned >1 times
# 100.00% overall alignment rate
# 4562 reads; of these:
#   4562 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4552 (99.78%) aligned exactly 1 time
#     10 (0.22%) aligned >1 times
# 100.00% overall alignment rate
# 5383 reads; of these:
#   5383 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5372 (99.80%) aligned exactly 1 time
#     11 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 5113 reads; of these:
#   5113 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5106 (99.86%) aligned exactly 1 time
#     7 (0.14%) aligned >1 times
# 100.00% overall alignment rate
# 5193 reads; of these:
#   5193 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5184 (99.83%) aligned exactly 1 time
#     9 (0.17%) aligned >1 times
# 100.00% overall alignment rate
# 5187 reads; of these:
#   5187 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5173 (99.73%) aligned exactly 1 time
#     14 (0.27%) aligned >1 times
# 100.00% overall alignment rate
# 5579 reads; of these:
#   5579 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5570 (99.84%) aligned exactly 1 time
#     9 (0.16%) aligned >1 times
# 100.00% overall alignment rate
# 5370 reads; of these:
#   5370 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5365 (99.91%) aligned exactly 1 time
#     5 (0.09%) aligned >1 times
# 100.00% overall alignment rate
# 5184 reads; of these:
#   5184 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5172 (99.77%) aligned exactly 1 time
#     12 (0.23%) aligned >1 times
# 100.00% overall alignment rate
# 6215 reads; of these:
#   6215 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     6203 (99.81%) aligned exactly 1 time
#     12 (0.19%) aligned >1 times
# 100.00% overall alignment rate
# 6201 reads; of these:
#   6201 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     6186 (99.76%) aligned exactly 1 time
#     15 (0.24%) aligned >1 times
# 100.00% overall alignment rate
# 5366 reads; of these:
#   5366 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5355 (99.80%) aligned exactly 1 time
#     11 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 4367 reads; of these:
#   4367 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4357 (99.77%) aligned exactly 1 time
#     10 (0.23%) aligned >1 times
# 100.00% overall alignment rate
# 5110 reads; of these:
#   5110 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5100 (99.80%) aligned exactly 1 time
#     10 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 6190 reads; of these:
#   6190 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     6181 (99.85%) aligned exactly 1 time
#     9 (0.15%) aligned >1 times
# 100.00% overall alignment rate
# 4721 reads; of these:
#   4721 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4713 (99.83%) aligned exactly 1 time
#     8 (0.17%) aligned >1 times
# 100.00% overall alignment rate
# 5548 reads; of these:
#   5548 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5536 (99.78%) aligned exactly 1 time
#     12 (0.22%) aligned >1 times
# 100.00% overall alignment rate
# 5115 reads; of these:
#   5115 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5107 (99.84%) aligned exactly 1 time
#     8 (0.16%) aligned >1 times
# 100.00% overall alignment rate
# 4845 reads; of these:
#   4845 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4831 (99.71%) aligned exactly 1 time
#     14 (0.29%) aligned >1 times
# 100.00% overall alignment rate
# 5372 reads; of these:
#   5372 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5362 (99.81%) aligned exactly 1 time
#     10 (0.19%) aligned >1 times
# 100.00% overall alignment rate
# 5095 reads; of these:
#   5095 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5085 (99.80%) aligned exactly 1 time
#     10 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 6222 reads; of these:
#   6222 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     6210 (99.81%) aligned exactly 1 time
#     12 (0.19%) aligned >1 times
# 100.00% overall alignment rate
# 5547 reads; of these:
#   5547 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5533 (99.75%) aligned exactly 1 time
#     14 (0.25%) aligned >1 times
# 100.00% overall alignment rate
# 5721 reads; of these:
#   5721 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5714 (99.88%) aligned exactly 1 time
#     7 (0.12%) aligned >1 times
# 100.00% overall alignment rate
# 5187 reads; of these:
#   5187 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5175 (99.77%) aligned exactly 1 time
#     12 (0.23%) aligned >1 times
# 100.00% overall alignment rate
# 4450 reads; of these:
#   4450 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4441 (99.80%) aligned exactly 1 time
#     9 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 5100 reads; of these:
#   5100 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5094 (99.88%) aligned exactly 1 time
#     6 (0.12%) aligned >1 times
# 100.00% overall alignment rate
# 4085 reads; of these:
#   4085 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4080 (99.88%) aligned exactly 1 time
#     5 (0.12%) aligned >1 times
# 100.00% overall alignment rate
# 4241 reads; of these:
#   4241 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4235 (99.86%) aligned exactly 1 time
#     6 (0.14%) aligned >1 times
# 100.00% overall alignment rate
# 5390 reads; of these:
#   5390 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     5382 (99.85%) aligned exactly 1 time
#     8 (0.15%) aligned >1 times
# 100.00% overall alignment rate
# 6220 reads; of these:
#   6220 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     6207 (99.79%) aligned exactly 1 time
#     13 (0.21%) aligned >1 times
# 100.00% overall alignment rate
# 4468 reads; of these:
#   4468 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4459 (99.80%) aligned exactly 1 time
#     9 (0.20%) aligned >1 times
# 100.00% overall alignment rate
# 4634 reads; of these:
#   4634 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     4631 (99.94%) aligned exactly 1 time
#     3 (0.06%) aligned >1 times
# 100.00% overall alignment rate
# 6212 reads; of these:
#   6212 (100.00%) were unpaired; of these:
#     0 (0.00%) aligned 0 times
#     6201 (99.82%) aligned exactly 1 time
#     11 (0.18%) aligned >1 times
# 100.00% overall alignment rate

# %% [markdown]
# ## Calculate the genotypes
#
# Next, we can calculate the genotypes for all of the individuals. We did this two classes ago and now just need to keep track of it for each person. Our end goal of this step is mostly just reformatting the data (this is very common in bioinformatics). We would like to have an array of variants by samples that contains the genotype of a sample for each variant. To build a master variant list, we will be using the criteria of common variants (>1% population frequency). This reduces the number of tests that we will have to perform.
#
# The first step of this will be to collate all of the variants into a list:

# %%
from genotyper import *

#calculate the genotypes for all the individuals, and now we need to keep track of it for each individual. 
#this function will 

def get_all_variants():
    ''' Function to iterate through all DNA files to get genotypes
    
    This functions runs our previous find_variants() function on all of the individuals and makes a list of these
    
    Example:
        >>> get_all_variants() #doctest: +ELLIPSIS
        [(803, 'C', 'A'), (5144, 'G', 'C'), (5275, 'T', 'T'), ...
    '''
    individual_variants = []

    # Note that this now starts at index 0
    for i in range(1, 101):
        # Run find_variants and store in a list indexed by sample
        individual_variants.append(find_variants(reference = '../class_09/data/sample_genome.fna', alignments = 'data/DNA/sample_reads_P' + str(i) + '.bam'))

    return individual_variants

# %%
# This takes a few minutes to run
#this sets it to a variable name. 
individual_genotypes = get_all_variants()
# Out:
#  UserWarning:/Users/alauth/opt/anaconda3/envs/b529/lib/python3.7/site-packages/bamnostic/bam.py:310: No supplied index file was not found. Random access disabled

# %%
# print(individual_genotypes)

# %% [markdown]
# The next step will be to first identify our final variant list (`build_list_of_common_variants`) and then use that list along with the list of genotypes to build our final bulk matrix described above (`build_bulk_genotype`).

# %%
from collections import Counter
import numpy as np

def build_list_of_common_variants(individual_genotypes):
    ''' This function will combine all of the genotypes to create a master list of SNP locations
        for common variants. Common variants are those that appear at a frequency of more than 1%
        in the population.
        
        Note: we only need to track the position of the SNPs
    '''
    
    all_variant_counter = Counter()
    all_variant_list = []
    #which variants are the most common aka they are above 1% threshold statistically 
    
    
    # Here I use a Counter() to just count the frequency of each variant location across the samples
    for i, sample in enumerate(individual_genotypes):
        for j, variant in enumerate(sample):
            position, allele1, allele2 = variant
            all_variant_counter[position] += 1
            
            print(all_variant_counter)
    
    # Now we create a list from just the counters that are above 1% (or 1 since we have 100 samples)
    for key in list(all_variant_counter):
        if all_variant_counter[key] > 1:
            all_variant_list.append(key)
            
            # print(key)
            
    return all_variant_list
    
def build_bulk_genotype(all_variants, individual_genotypes):
    ''' This function will assign one of 3 genotypes at every SNP location
    ref/ref = 0  check and see if a particular position was called in a sample. 
    ref/alt = 1
    alt/alt = 2
    
    This will populate a varaint x individual matrix with the 2 genotypes maintaining individual order from 
    individual_genotypes and variant order from all_variants
    
    Pseudocode:
    For each variant
        For each individual
            if individual has variant assign value 1 if het, 2 if homozygous alt
            otherwise value is 0
    
    Args:
        all_variants (list): list of common variants
        individual_genotypes (list of list of tuples): list of all variants for each individual
        
    Returns:
        sample_variant_matrix (numpy int matrix): matrix of variants x individuals
 
    '''
    
    #all_variants (SNPs with just positions) so this SNP was present in at least 2 people in this 100 population group 
    #individl contains the position, ref all, alt all, 
    #index indivual_genotypes with positino from all variants, then compare alleles 
    #then plug and chug into the array. 
    #if ref/ref need to iterate through rest of pop and if they don't have it, put a "-" 
    
    #initialize the empty matrix here:
    sample_variant_matrix = np.zeros((len(all_variants), len(individual_genotpyes)), dtype=int)
    
    
    #for each variant
    for index, variant_pos in enumerate(all_variants):
        #for loop through each individual
        for index2, variants in enumerate(individual_genotypes):
            #if we have not seen the variant it is zero (homozygous) 
            #our initial (if its ref/ref)
            sample_genotype = 0
            
            #all the individual genotypes for each individual. 
            #must remember that each individual has it's own individual genotypes too, so you need to index for that too. 
            #that is why you need to index further. 
            for index3, variant in enumerate(individual_genotypes[index2]):
                pos, allele1, allele2 = variant
                if pos == variant_pos:
                    if allele1 == allele2:
                        #homozygous alternative 
                        sample_genotype = 2
                    if allele1 != allele2:
                        #heterozygous 
                        sample_genotype = 1
                    break 
                
            #need the position that is index of the all_variants and the individual_genotypes. 
            sample_variant_matrix[index][index2] = sample_genotype  
    
    
    return sample_variant_matrix
                
    #now need to iterate through the variant list (call the helper funtion and now the individual_genotypes. 
    # Pseudocode:
    # For each variant
    #     For each individual
    #         if individual has variant assign value 1 if het, 2 if homozygous alt
    #         otherwise value is 0
    
    
    #reference allele if you don't have a record for that position, then that's the reference. 
    
#take genotypes and associate them with gene expression in the samples 
#doing a linear model, how genotype as a category is associated with a continuous variable in the RPKMs. 
#we care about the category (homo, or hetero) 
    
#go through each of the tuples and check if they are 
#aggregate list of all the positions,

# %%
# # # Now we get the final bulk_genotype matrix
# full_variant_list = build_list_of_common_variants(individual_genotypes)
# bulk_genotypes = build_bulk_genotype(full_variant_list, individual_genotypes)
# print(bulk_genotypes)

# %% [markdown]
# ## Calculate the gene expression
#
# In addition to the genotype matrix above, we also need to generate expression data for all of the individuals at each gene. To do this, we can use the methods from the previous class `get_transcript_levels` to get the expression level of each gene for each person. As above, we will store this as a matrix of gene by samples with RPKM in each position of the matrix.

# %%
from rna_tools import *

def get_all_expression():
    ''' Function to iterate through all RNA file to get expression levels of genes
    '''
    individual_expression_matrix = np.zeros((5,100), dtype=float)

    # Note that this now starts at index 0
    for i in range(1, 101):
        # Run our get_transcript_levels for all individuals
        individual_expression = get_transcript_levels('data/RNA/sample_RNA_reads_P' + str(i) + '.bam', '../class_10/data/sample_genomic.gff')
        for j, data in enumerate(individual_expression):
            seqid, start, end, expression = data
            individual_expression_matrix[j][i-1] = expression # Just save the expression value
        
    return individual_expression_matrix

# %%
# This takes a few minutes to run
bulk_expression = get_all_expression()

# %% [markdown]
# ## eQTL Analysis
#
# As discussed in the class materials, the variants that we have identified from our diploid samples represent polymorphic locations in the sample genomes. These sites can sometimes affect the regulation or expression level of a gene, often through disruption of transcription factor binding. Identifying variants associated with this change in expression is thus of great interest in understanding how the gene expression might be controlled. To do this, we use eQTL analysis.
#
# Standard eQTL analysis involves direct pairwise testing between genetic markers (here SNPs) andd the gene expression levels across many (here 100) individuals. This can be done for all SNPs vs all genes, but this results in a large penalty when accounting for multiple testing. To avoid this, the analysis is often done in a window around each gene of ~ 1 magabase. For our example today, we can just test all of the variants because our genome is quite small.
#
# Typical eQTL analysis uses a generalized linear model (GLM). For simplicity, we will use a simple linear model of the form $Y_{i} = b_{0} + b_{1}X_{i} + \epsilon_{i}$ where $Y_{i}$ is the RPKM for individual $i$ and $X_{i}$ indicates the genotype (0, 1, 2) at a given SNP. We can implement this with the `stats.linregress()` function in scipy ( https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.linregress.html ).
#
# We can also plot these associations using `matplotlib.pyplot` ( https://matplotlib.org/api/_as_gen/matplotlib.pyplot.html ).
#
# <img src = "figures/eQTL_fig.png">
#
# Today, generate the variant and gene associations that are significant ($p < .01$) and plot these below:

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

def eQTL_analysis(bulk_genotypes, bulk_expression):
    ''' Function to perform eQTL analysis
    
    Args:
        bulk_genotypes (2D np array): genotypes for each variant for each individual
        bulk_expression (2D np array): expression values for each gene for each individual
       
    Prints:
        significant eQTLs (p < .01) and plots them as above
    '''
    
    for gene_index in range(bulk_expression.shape[0]):
        y = np.array(bulk_expression[gene_index]) #give us all the values from the gene_index. 
        
        for snp_index in range(bulk_genotypes.shape[0]):
            xi = np.array(bulk_genotypes[snp_index])
            slope, intercept, r_value, p_value, std_err = stats.lineregress(xi, y)
            
            if p_value < 0.1:
                print("significant eQTL: ", "gene", gene_index, "snp", snp_index, "p_value", p_value)
                line = slope * xi * intercept 
                
                plt.plot(xi, line, "r-", xi, y, "o")
                plt.show()

# %%
eQTL_analysis(bulk_genotypes, bulk_expression)
